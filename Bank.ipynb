# %%
print("Welcome to the bank *DRAGON'S DEN*, Traveler!")

balance = 0

def get_user_choice(text, valid_choices):
  while True:
    choice = input(text)
    if choice in valid_choices:
      return choice
    print('\nDragon does not understand you!')

def deposit(balance):
  while True:
    try:
      amount = int(input('\nPlease insert the amount of golden coins you want to deposit: '))
      return balance + amount
    except ValueError:
      print('\nDragon does not understand you!')

def withdrowal(balance):
  while True:
    try:
      amount = int(input('\nPlease insert the amount of golden coins you want to withdraw: '))
      if amount > balance:
        print('\nYou do not have enough money in your account!')
      else:
        return balance - amount
    except ValueError:
      print('\nDragon does not understand you!')

def main():
  global balance

  while True:

    user_choice = get_user_choice("\nWhat would you like to do?\n1. Deposit money\n2. Withdraw money\n3. Check balance\n4. Exit\nYour choice is: ", ['1', '2', '3','4'])

    if user_choice == '1':
      balance = deposit(balance)
    elif user_choice == '2':
      balance = withdrowal(balance)
    elif user_choice == '3':
      print(f'\nYour balance is {balance}.')
    elif user_choice == '4':
      print(f'\nThe total amount deposited is {balance} golden coins.\nFarewell, Traveler!')
      break
    else:
      print('\nDragon does not understand what you say. Choose a valid option!')

main()
# Out:
# Welcome to the bank *DRAGON'S DEN*, Traveler!
#
# What would you like to do?
# 1. Deposit money
# 2. Withdraw money
# 3. Check balance
# 4. Exit
# Your choice is: 1
#
# Please insert the amount of golden coins you want to deposit: 50
#
# What would you like to do?
# 1. Deposit money
# 2. Withdraw money
# 3. Check balance
# 4. Exit
# Your choice is: 3
#
# Your balance is 50.
#
# What would you like to do?
# 1. Deposit money
# 2. Withdraw money
# 3. Check balance
# 4. Exit
# Your choice is: 1
#
# Please insert the amount of golden coins you want to deposit: 100
#
# What would you like to do?
# 1. Deposit money
# 2. Withdraw money
# 3. Check balance
# 4. Exit
# Your choice is: 3
#
# Your balance is 150.
#
# What would you like to do?
# 1. Deposit money
# 2. Withdraw money
# 3. Check balance
# 4. Exit
# Your choice is: 2
#
# Please insert the amount of golden coins you want to withdraw: 30
#
# What would you like to do?
# 1. Deposit money
# 2. Withdraw money
# 3. Check balance
# 4. Exit
# Your choice is: 3
#
# Your balance is 120.
#
# What would you like to do?
# 1. Deposit money
# 2. Withdraw money
# 3. Check balance
# 4. Exit
# Your choice is: w
#
# Dragon does not understand you!
#
# What would you like to do?
# 1. Deposit money
# 2. Withdraw money
# 3. Check balance
# 4. Exit
# Your choice is: 2
#
# Please insert the amount of golden coins you want to withdraw: 180
#
# You do not have enough money in your account!
#
# Please insert the amount of golden coins you want to withdraw: y
#
# Dragon does not understand you!
#
# Please insert the amount of golden coins you want to withdraw: t
#
# Dragon does not understand you!
#
# Please insert the amount of golden coins you want to withdraw: 2
#
# What would you like to do?
# 1. Deposit money
# 2. Withdraw money
# 3. Check balance
# 4. Exit
# Your choice is: 1
#
# Please insert the amount of golden coins you want to deposit: u
#
# Dragon does not understand you!
#
# Please insert the amount of golden coins you want to deposit: 5
#
# What would you like to do?
# 1. Deposit money
# 2. Withdraw money
# 3. Check balance
# 4. Exit
# Your choice is: 4
#
# The total amount deposited is 123 golden coins.
# Farewell, Traveler!
